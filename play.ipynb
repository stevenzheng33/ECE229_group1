# %%
import pandas as pd

# %%
df = pd.read_csv('death_causes.csv')

# %%
df
# Out:
#     Year  All causes  Heart disease  Cancer   Unintentional injuries  CLRD  \
# 0   2008       774.9          192.1    176.4                    39.2  44.7
# 1   2009       749.6          182.8    173.5                    37.5  42.7
# 2   2010       747.0          179.1    172.8                    38.0  42.2
# 3   2011       741.3          173.7    169.0                    39.1  42.5
# 4   2012       732.8          170.5    166.5                    39.1  41.5
# 5   2013       731.9          169.8    163.2                    39.4  42.1
# 6   2014       724.6          167.0    161.2                    40.5  40.5
# 7   2015       733.1          168.5    158.5                    43.2  41.6
# 8   2016       728.8          165.5    155.8                    47.4  40.6
# 9   2017       731.9          165.0    152.5                    49.4  40.9
# 10  2018       723.6          163.6    149.1                    48.0  39.7
#
#     Stroke  Alzheimer's disease  Diabetes
# ...

# %%
df = df.set_index('Year')

# %%
df.columns
# Out:
# Index(['All causes', 'Heart disease', 'Cancer ', 'Unintentional injuries',
#        'CLRD', 'Stroke', 'Alzheimer's disease', 'Diabetes'],
#       dtype='object')

# %%
df[['Heart disease']]
# Out:
#       Heart disease
# Year
# 2008          192.1
# 2009          182.8
# 2010          179.1
# 2011          173.7
# 2012          170.5
# 2013          169.8
# 2014          167.0
# 2015          168.5
# 2016          165.5
# 2017          165.0
# 2018          163.6
