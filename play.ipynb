# %%
import pandas as pd

# %%
user_data = {
"HeartDisease":"Yes",
"BMI":30,
"Smoking":"True",
"AlcoholDrinking":"True",
"Stroke":"True",
"DiffWalking":"True",
"Sex":"Male",
"AgeCategory":"45-49",
"Race":"American Indian/Alaskan Native",
"Diabetic":"True",
"PhysicalActivity":"True",
"GenHealth":"Fair",
"SleepTime":8,
"Asthma":"True",
"KidneyDisease":"True",
"SkinCancer":"False"
}

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df = pd.read_csv('heart_2020_cleaned.csv')
user_data = pd.Series(user_data)
df_test = df.copy()
df_test = df_test.drop(['PhysicalHealth','MentalHealth'],axis = 1)
df_test.loc[len(df_test.index)] = user_data.values

# %%
len(user_data.values)
# Out:
# 16

# %%
df_test.loc[len(df_test.index)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 319795 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/8r/42mrjtjd313fzr38pl87_b0r0000gn/T/ipykernel_82751/2843884147.py in <module>
# ----> 1 df_test.loc[len(df_test.index)]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# ...
